# %%
import pymysql
import pandas as pd
from sqlalchemy import create_engine

host = '127.0.0.1'
port = '3306'
user = 'root'
password = ''
database = 'BIGDATA'

# Create Connection to database
engine = create_engine('mysql+pymysql://'+user+':'+password+'@'+host+':'+port+'/'+database)
'''engine = create_engine('mysql+pymysql://root: @localhost:3306/academic')'''

def run(sql):
    df = pd.read_sql_query(sql, engine)
    return df

# %%
# # CSV to DataFrame to MySQL
# df_fromcsv = pd.read_csv('20150101.export.csv')
# df_fromcsv.to_sql(name = 'gdelt', con = engine, if_exists = 'append', index = False) 
# #if_exists = 'fail' | 'replace' | 'append'
file_p = '20150101.export.csv'
data_df = pd.read_csv(file_p, sep="\t", header=None)
data_df.to_sql('gdelt',con=engine,if_exists='replace',index=False)
# Out:
# E:\ANACONDA\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (8,9,11,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# E:\ANACONDA\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1169                         parameters,
# -> 1170                         context)
#    1171             elif not parameters and context.no_parameters:
#
# E:\ANACONDA\lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py in do_executemany(self, cursor, statement, parameters, context)
#     104     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 105         rowcount = cursor.executemany(statement, parameters)
# ...
